# %% [markdown]
# <a href="https://colab.research.google.com/github/lszam/geodata-processing/blob/main/grdSurfer_2_nc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio rioxarray -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 3.7 MB/s eta 0:00:00

# %%
import xarray as xr
import rasterio
import rioxarray
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Fazer o upload de arquivo. Depois, descompactar.

# %%
# Descompactar arquivo zip
# !unzip /content/BR-DTM-REV2024.zip -d /content/
# Out:
# Archive:  /content/BR-DTM-REV2024.zip
#   inflating: /content/BR-DTM-REV2024.grd.xml
#   inflating: /content/BR-DTM-REV2024.spc
#   inflating: /content/BR-DTM-REV2024.grd.aux.xml
#   inflating: /content/BR-DTM-REV2024.grd
#   inflating: /content/BR-DTM-REV2024.grd.gi

# %%
# prompt: converter o grid tipo surfer BR-DTM-REV2024.grd em um arquivo .nc

import rioxarray

# Abra o arquivo .grd usando rioxarray
# Substitua '/content/BR-DTM-REV2024.grd' pelo caminho correto do seu arquivo
ds = rioxarray.open_rasterio('/content/BR-DTM-REV2024.grd')

# Salve o arquivo como NetCDF (.nc)
# Substitua '/content/BR-DTM-REV2024.nc' pelo caminho desejado para o arquivo .nc
ds.rio.to_raster('/content/BR-DTM-REV2024.nc')
# Out:
# WARNING:rasterio._env:CPLE_NotSupported in driver netCDF does not support creation option BLOCKXSIZE
# WARNING:rasterio._env:CPLE_NotSupported in driver netCDF does not support creation option BLOCKYSIZE

# %%
# Verificar arquivo de saída
ds = xr.open_dataset('/content/BR-DTM-REV2024.nc')
ds
# Out:
# <xarray.Dataset> Size: 144MB
# Dimensions:  (lat: 5707, lon: 3159)
# Coordinates:
#   * lat      (lat) float64 46kB -4.482e+06 -4.481e+06 ... 1.223e+06 1.224e+06
#   * lon      (lon) float64 25kB -5.941e+06 -5.94e+06 ... -2.784e+06 -2.783e+06
# Data variables:
#     Band1    (lat, lon) float64 144MB ...
# Attributes:
#     Conventions:                    CF-1.5
#     GDAL:                           GDAL 3.9.3, released 2024/10/07
#     history:                        Sat Mar 08 12:39:08 2025: GDAL Create( /c...
#     GDAL_STATISTICS_APPROXIMATE:    YES
#     GDAL_STATISTICS_MAXIMUM:        88.267486572266
#     GDAL_STATISTICS_MEAN:           -3925.5117212509
#     GDAL_STATISTICS_MINIMUM:        -6072.2377929688
#     GDAL_STATISTICS_STDDEV:         1401.526949257
#     GDAL_STATISTICS_VALID_PERCENT:  69.88

# %%
# Download do arquivo .nc de saída
from google.colab import files
files.download('/content/BR-DTM-REV2024.nc')
